# %% [markdown]
# # Crowd dynamics simulation — a multi-agent system based on CA (16 points)

# %% [markdown]
# Today you'll create a more complex simulation of crowd dynamics. We are trying to model the movement of people trying to leave a room (e.g. lectureroom, stadium etc.). The room has one or more exit and people insidie want to leave it using the closest exit. The model uses static field which can be treated as a *distance* to the closest exit. Agents move toward the exits by choosing the cells with the smallest value of static field in their neighbourhoods. Static field is also used to simulate walls (wall is a cell with ridiculously high static field value, so no agent will choose it).
#
#
# ## (2 points) Neighbourhood initialisation — `Board` Class
# Fill in the missing part of the `__init__` method in the `Board` class. Use Moore neighbourhood. **Do not initialise neighbourhoods for border cells.**
# ![image](https://upload.wikimedia.org/wikipedia/commons/8/86/CA-Moore.svg)
#
# <center>Moore neighbourhood (source: <a href="https://commons.wikimedia.org/wiki/File:CA-Moore.svg">wikimedia.org</a>)</center>
#
# ## (3 points) Static potential field
#
# ### Implement `calculateField` method in the `Board` class:
# * Create a list of points (`toCheck`) for which the static field should be recalculated (initially each cell's `staticField` is equal to `100000`).
# * Change `staticField` of all exits (points with `pointType == 2`) to `0`.
# * Add all exits' neighbours to the `toCheck` list.
# * Until the `toCheck` list is empty:
#     * check if the `staticField` of the first element of the list has changed (to do so call its `calcStaticField()` method).
#     * If the value changed, add all neighbours of this cell to the end of the `toCheck` list.
#     * Remove the first element from the list.
#
# ### Implement `calcStaticField` method in the `Point` class:
# * Find the smallest `staticField` in the cell's neighbourhood.
# * If the cell's `staticField` is greater than the found value + 1 (`self.staticField > neighbourMin + 1`), change the `staticField` to this value (i.e. `neighbourMin + 1`) and return `True`, otherwise do not change anything and return `False`. **Do not change walls static fields**.
#
# ## (3 points) Implement `createBoard` method in the `Board` class:
# * (1 point) Add some walls and pedestrians, add at least one exit.
# * (2 points) Create a random version of this method (call it `randomBoard`), try to generate walls in patterns.
#
# ## Naive Implementation (6 points)
#
# ### Implement `move` method in the `Point` class:
# * If the cell represents a pedestrian (`pointType == 3`), move the pedestrian to the neighbouring cell with the smallest `staticField`.
# * Run the simulation and observe what is happening.
# * Is everything working as it should? If not, what's wrong? How can we fix it?
#
# ## First improvements (4 points)
# There are two main reasons responsible for the visible errors:
# * There is no *exit* mechanism. After reaching the exit, the agent should be removed from the `Board`.
# * No cells synchronisation. One should note that agents moving down and right can reach the destination in one iteration. To fix this issue you can add a boolean value `isBlocked = false` to the `Point` class. After the agent moves, the `isBlocked` value of the occupied cell should be change to `True`. Remember to *unblock* all cells at the beginning of each iteration.
#
# Correct the errors and create a complex board with walls, many pedestrians and at least two exits. Check the behaviour of agents. Is everything right? Any other problems?

# %%
import numpy as np
import itertools
import pygame
import random
import copy

from pygame.locals import (
    K_UP,
    K_DOWN,
    K_LEFT,
    K_RIGHT,
    K_ESCAPE,
    KEYDOWN,
    QUIT,
)

# %% [markdown]
# ## `Point` class

# %%
class Point:
    def __init__(self):
        # 0 - floor, 1 - wall, 2 - exit, 3 - pedestrian
        self.pointType = 0
        self.staticField = 1000
        self.neighbours = []
        self.isBlocked = False

    def clear(self):
        self.staticField = 100000

    def calcStaticField(self):
        neighbourMin = min(
            [neighbour.staticField for neighbour in self.neighbours 
             if neighbour.pointType != 1]  # Exclude walls
        ) if self.neighbours else 100000

        if self.pointType != 1 and self.staticField > neighbourMin + 1:
            self.staticField = neighbourMin + 1
            return True
        return False

    def move(self):
        if self.pointType != 3:
            return
        if self.isBlocked:
            return
        
        def correct_neighbour(n):
            if (n.pointType == 1) or (n.pointType == 3):
                return False
            if n.isBlocked:
                return False
            return True
        
        movable_neighbours = [
            n for n in self.neighbours 
            if correct_neighbour(n)
        ]


        print("Movable neighbours: ", len(movable_neighbours))
        print("Static field values: ", [n.staticField for n in movable_neighbours])

        if not movable_neighbours:
            return
        target = min(movable_neighbours, key=lambda n: n.staticField)
        print("Target: ", target.staticField)
        if target.pointType == 2:
            self.pointType = 0  # Current cell becomes floor
            return

        # Move pedestrian
        target.pointType = 3
        self.pointType = 0
        target.isBlocked = True

    def getColour(self):
        if self.pointType == 0:
            # Floor
            return (243, 243, 243)
        elif self.pointType == 1:
            # Wall
            return (255, 191, 0)
        elif self.pointType == 2:
            # Exit
            return (0, 255, 56)
        else:
            # Pedestrian
            return (0, 39, 255)

# %% [markdown]
# # `Board` class

# %%
class Board:
    def __init__(self, xSize=40, ySize=40):
        self.points = [[Point() for i in range(0, ySize)] for j in range(0, xSize)]
        
        for i in range(1, len(self.points)-1):
            for j in range(1, len(self.points[0])-1):
                self.points[i][j].neighbours = [
                    self.points[i+dx][j+dy] 
                    for dx in [-1, 0, 1] 
                    for dy in [-1, 0, 1] 
                    if (dx != 0 or dy != 0)
                ]

    def calculateField(self):
        # Reset static field
        for row in self.points:
            for point in row:
                if point.pointType == 2:
                    point.staticField = 0
                else:
                    point.staticField = 1000

        toCheck = []
        for i in range(len(self.points)):
            for j in range(len(self.points[0])):
                if self.points[i][j].pointType == 2:
                    self.points[i][j].staticField = 0
                    for dx in [-1, 0, 1]:
                        for dy in [-1, 0, 1]:
                            ni, nj = i+dx, j+dy
                            if dx == 0 and dy == 0:
                                continue
                            if (0 <= ni < len(self.points) and 
                                0 <= nj < len(self.points[0]) and 
                                self.points[ni][nj].pointType != 1):
                                toCheck.append(self.points[ni][nj])

        while toCheck:
            current = toCheck.pop(0)
            if current.calcStaticField():
                # If static field changed, add neighbours
                for neighbour in current.neighbours:
                    if neighbour.pointType != 1 and neighbour not in toCheck:
                        toCheck.append(neighbour)

    def createBoard(self):
        for i in range(len(self.points)):
            self.points[i][0].pointType = 1
            self.points[i][-1].pointType = 1
            self.points[0][i].pointType = 1
            self.points[-1][i].pointType = 1

        self.points[len(self.points)//2][0].pointType = 2
        
        for _ in range(20):
            x = random.randint(5, len(self.points)-6)
            y = random.randint(5, len(self.points[0])-6)
            self.points[x][y].pointType = 3

        self.calculateField()

    def randomBoard(self):
        for i in range(len(self.points)):
            for j in range(len(self.points[0])):
                if random.random() < 0.2 and i % 5 == 0:
                    self.points[i][j].pointType = 1

        self.points[0][0].pointType = 2
        self.points[0][-1].pointType = 2
        
        # Add pedestrians
        for _ in range(50):
            x = random.randint(5, len(self.points)-6)
            y = random.randint(5, len(self.points[0])-6)
            self.points[x][y].pointType = 3

        # Calculate initial static field
        self.calculateField()

    def iteration(self):
        # Unblock all cells at start of iteration
        for row in self.points:
            for point in row:
                point.isBlocked = False

        for i in range(1, len(self.points)-1):
            for j in range(1, len(self.points[0])-1):
                if self.points[i][j].pointType == 3:
                    print("Moving pedestrian", i, j)
                    self.points[i][j].move()

    def clear(self):
        for i in range(1, len(self.points)-1):
            for j in range(1, len(self.points[0])-1):
                self.points[i][j].clear()
        self.calculateField()

    def drawGrid(self, screen, w_width, w_height):
        rows = len(self.points)
        cols = len(self.points[0])
        blockSize = (min(w_width, w_height)-max(rows, cols))/max(rows, cols)

        for x in range(0, rows):
            for y in range(0, cols):
                pos_x = (blockSize+1) * x
                pos_y = (blockSize+1) * y
                rect = pygame.Rect(pos_x, pos_y, blockSize, blockSize)
                pygame.draw.rect(screen, self.points[x][y].getColour(), rect, 0)    
        pygame.display.flip()
        
    
    # For debug, get numpy arrays of field and 
        
    def getFloorFieldValues(self):
        # Returns numpy array of fieldValues
        fig = np.zeros((len(self.points),len(self.points[0])))
        for i in range(0,len(self.points)):
            for j in range(0, len(self.points[0])):
                fig[i][j] = self.points[i][j].staticField
        return fig
    
    def getPointTypes(self):
        # Returns numpy array of colours
        fig = np.zeros((len(self.points),len(self.points[0])))
        for i in range(0,len(self.points)):
            for j in range(0, len(self.points[0])):
                fig[i][j] = self.points[i][j].pointType
        return fig

# %% [markdown]
# # `Pygame` stuff

# %%
def prettyPrintBoard(board):
    values = board.getFloorFieldValues()
    for i in range(0, len(values)):
        for j in range(0, len(values[0])):
            # format as float as decimal
            print("{:.0f}".format(values[j][i]), end="\t ")
        print()
    print("________________")

pygame.init()
# Parameters
w_width = 800
w_height = 800
# Set up the drawing window, adjust the size
screen = pygame.display.set_mode([w_width, w_height])

# Create Board object
board = Board()



# Set background
screen.fill((255, 255, 255))

# Add walls, exits & humans
board.randomBoard()
# Calculate static fields
board.calculateField()

# Draw grid
board.drawGrid(screen, w_width, w_height)
    
running = True

time_delay = 200 # 0.2 s
timer_event = pygame.USEREVENT + 1
pygame.time.set_timer(timer_event, time_delay )

while running:
    for event in pygame.event.get():   
        if event.type == QUIT:
            running = False
        
        if event.type == KEYDOWN:
            if event.key == K_RIGHT:
                board.iteration()
                board.drawGrid(screen, w_width, w_height)
        continue
        if event.type == timer_event:
            board.iteration()
            board.drawGrid(screen, w_width, w_height)

pygame.quit()
# Out:
# Moving pedestrian 5 18
# Movable neighbours:  8
# Static field values:  [17, 18, 19, 17, 19, 17, 18, 19]
# Target:  17
# Moving pedestrian 5 31
# Movable neighbours:  8
# Static field values:  [9, 8, 7, 9, 7, 9, 8, 8]
# Target:  7
# Moving pedestrian 7 8
# Movable neighbours:  8
# Static field values:  [7, 8, 9, 7, 9, 8, 8, 9]
# Target:  7
# Moving pedestrian 7 12
# Movable neighbours:  8
# Static field values:  [11, 12, 13, 11, 13, 11, 12, 13]
# Target:  11
# Moving pedestrian 7 18
# Movable neighbours:  8
# Static field values:  [17, 18, 19, 17, 19, 17, 18, 19]
# Target:  17
# Moving pedestrian 7 26
# Movable neighbours:  7
# Static field values:  [14, 13, 12, 14, 12, 14, 13]
# Target:  12
# Moving pedestrian 8 16
# Movable neighbours:  8
# Static field values:  [15, 16, 17, 15, 17, 15, 16, 17]
# Target:  15
# Moving pedestrian 8 27
# Movable neighbours:  8
# Static field values:  [13, 12, 11, 13, 11, 13, 12, 11]
# Target:  11
# Moving pedestrian 8 29
# Movable neighbours:  7
# Static field values:  [10, 9, 11, 10, 11, 11, 10]
# Target:  9
# Moving pedestrian 9 32
# Movable neighbours:  8
# Static field values:  [9, 8, 8, 9, 9, 10, 10, 10]
# Target:  8
# Moving pedestrian 10 24
# Movable neighbours:  7
# Static field values:  [16, 15, 14, 16, 16, 15, 14]
# Target:  14
# Moving pedestrian 10 28
# Movable neighbours:  8
# Static field values:  [12, 11, 11, 12, 11, 13, 12, 11]
# Target:  11
# Moving pedestrian 11 22
# Movable neighbours:  7
# Static field values:  [18, 17, 16, 18, 16, 18, 16]
# Target:  16
# Moving pedestrian 12 6
# Movable neighbours:  8
# Static field values:  [11, 11, 11, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 12 22
# Movable neighbours:  8
# Static field values:  [18, 17, 16, 18, 16, 18, 17, 16]
# Target:  16
# Moving pedestrian 13 24
# Movable neighbours:  8
# Static field values:  [16, 15, 14, 16, 15, 16, 16, 15]
# Target:  14
# Moving pedestrian 13 34
# Movable neighbours:  7
# Static field values:  [12, 12, 12, 13, 13, 14, 14]
# Target:  12
# Moving pedestrian 14 5
# Movable neighbours:  8
# Static field values:  [13, 13, 13, 14, 14, 15, 15, 15]
# Target:  13
# Moving pedestrian 14 7
# Movable neighbours:  8
# Static field values:  [13, 13, 13, 14, 14, 15, 15, 15]
# Target:  13
# Moving pedestrian 14 31
# Movable neighbours:  6
# Static field values:  [13, 13, 13, 14, 14, 15]
# Target:  13
# Moving pedestrian 14 33
# Movable neighbours:  8
# Static field values:  [13, 13, 13, 14, 14, 15, 15, 15]
# Target:  13
# Moving pedestrian 15 13
# Movable neighbours:  8
# Static field values:  [14, 14, 15, 15, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 16 27
# Movable neighbours:  4
# Static field values:  [16, 18, 17, 17]
# Target:  16
# Moving pedestrian 17 6
# Movable neighbours:  8
# Static field values:  [16, 16, 16, 17, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 17 8
# Movable neighbours:  8
# Static field values:  [16, 16, 16, 17, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 17 15
# Movable neighbours:  8
# Static field values:  [16, 16, 17, 17, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 17 18
# Movable neighbours:  8
# Static field values:  [17, 18, 19, 18, 19, 18, 19, 19]
# Target:  17
# Moving pedestrian 17 21
# Movable neighbours:  8
# Static field values:  [19, 18, 18, 19, 18, 20, 19, 18]
# Target:  18
# Moving pedestrian 17 28
# Movable neighbours:  8
# Static field values:  [17, 18, 18, 17, 18, 18, 18, 18]
# Target:  17
# Moving pedestrian 17 32
# Movable neighbours:  8
# Static field values:  [16, 16, 16, 17, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 19 28
# Movable neighbours:  8
# Static field values:  [18, 18, 18, 19, 19, 20, 20, 20]
# Target:  18
# Moving pedestrian 19 32
# Movable neighbours:  8
# Static field values:  [18, 18, 18, 19, 19, 20, 20, 20]
# Target:  18
# Moving pedestrian 20 20
# Movable neighbours:  7
# Static field values:  [20, 20, 19, 20, 21, 21, 21]
# Target:  19
# Moving pedestrian 21 33
# Movable neighbours:  7
# Static field values:  [20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 22 14
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 23 18
# Movable neighbours:  8
# Static field values:  [22, 22, 22, 23, 23, 24, 24, 24]
# Target:  22
# Moving pedestrian 26 24
# Movable neighbours:  4
# Static field values:  [25, 26, 26, 27]
# Target:  25
# Moving pedestrian 26 32
# Movable neighbours:  8
# Static field values:  [25, 25, 25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 27 23
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 27 25
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 27 34
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 28 13
# Movable neighbours:  8
# Static field values:  [27, 27, 27, 28, 28, 29, 29, 29]
# Target:  27
# Moving pedestrian 28 20
# Movable neighbours:  8
# Static field values:  [27, 27, 27, 28, 28, 29, 29, 29]
# Target:  27
# Moving pedestrian 29 30
# Movable neighbours:  7
# Static field values:  [28, 28, 28, 29, 29, 30, 30]
# Target:  28
# Moving pedestrian 30 14
# Movable neighbours:  7
# Static field values:  [29, 29, 29, 30, 31, 31, 31]
# Target:  29
# Moving pedestrian 31 12
# Movable neighbours:  6
# Static field values:  [30, 31, 31, 32, 32, 32]
# Target:  30
# Moving pedestrian 32 29
# Movable neighbours:  8
# Static field values:  [31, 31, 31, 32, 32, 33, 33, 33]
# Target:  31
# Moving pedestrian 33 6
# Movable neighbours:  8
# Static field values:  [32, 32, 32, 33, 33, 34, 34, 34]
# Target:  32
# Moving pedestrian 33 13
# Movable neighbours:  8
# Static field values:  [32, 32, 32, 33, 33, 34, 34, 34]
# Target:  32
# Moving pedestrian 34 33
# Movable neighbours:  8
# Static field values:  [33, 33, 33, 34, 34, 35, 35, 35]
# Target:  33
# Moving pedestrian 4 17
# Movable neighbours:  8
# Static field values:  [16, 17, 18, 16, 18, 16, 17, 18]
# Target:  16
# Moving pedestrian 4 32
# Movable neighbours:  7
# Static field values:  [8, 7, 6, 8, 6, 8, 7]
# Target:  6
# Moving pedestrian 6 7
# Movable neighbours:  7
# Static field values:  [6, 8, 6, 8, 7, 7, 8]
# Target:  6
# Moving pedestrian 6 11
# Movable neighbours:  7
# Static field values:  [10, 12, 10, 12, 10, 11, 12]
# Target:  10
# Moving pedestrian 6 17
# Movable neighbours:  8
# Static field values:  [16, 17, 18, 16, 18, 16, 17, 18]
# Target:  16
# Moving pedestrian 6 27
# Movable neighbours:  6
# Static field values:  [12, 11, 13, 11, 13, 12]
# Target:  11
# Moving pedestrian 7 15
# Movable neighbours:  8
# Static field values:  [14, 15, 16, 14, 16, 14, 15, 16]
# Target:  14
# Moving pedestrian 7 28
# Movable neighbours:  8
# Static field values:  [12, 11, 10, 12, 10, 12, 11, 10]
# Target:  10
# Moving pedestrian 7 30
# Movable neighbours:  7
# Static field values:  [9, 8, 10, 9, 10, 10, 9]
# Target:  8
# Moving pedestrian 8 32
# Movable neighbours:  8
# Static field values:  [9, 8, 7, 9, 8, 9, 9, 9]
# Target:  7
# Moving pedestrian 9 25
# Movable neighbours:  7
# Static field values:  [15, 14, 13, 15, 13, 15, 13]
# Target:  13
# Moving pedestrian 9 28
# Movable neighbours:  8
# Static field values:  [12, 11, 10, 12, 11, 12, 12, 11]
# Target:  10
# Moving pedestrian 10 23
# Movable neighbours:  7
# Static field values:  [17, 16, 15, 17, 15, 17, 15]
# Target:  15
# Moving pedestrian 11 5
# Movable neighbours:  8
# Static field values:  [10, 10, 10, 11, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 11 23
# Movable neighbours:  8
# Static field values:  [17, 16, 15, 17, 15, 17, 16, 15]
# Target:  15
# Moving pedestrian 12 25
# Movable neighbours:  8
# Static field values:  [15, 14, 13, 15, 14, 15, 15, 14]
# Target:  13
# Moving pedestrian 12 33
# Movable neighbours:  7
# Static field values:  [11, 11, 11, 12, 12, 13, 13]
# Target:  11
# Moving pedestrian 13 4
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 13 6
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 13 30
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 13 32
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 14 12
# Movable neighbours:  8
# Static field values:  [13, 13, 14, 14, 14, 15, 15, 15]
# Target:  13
# Moving pedestrian 16 5
# Movable neighbours:  8
# Static field values:  [15, 15, 15, 16, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 16 7
# Movable neighbours:  8
# Static field values:  [15, 15, 15, 16, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 16 14
# Movable neighbours:  8
# Static field values:  [15, 15, 16, 16, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 16 17
# Movable neighbours:  8
# Static field values:  [16, 17, 18, 17, 18, 17, 18, 18]
# Target:  16
# Moving pedestrian 16 21
# Movable neighbours:  7
# Static field values:  [18, 17, 19, 18, 19, 19, 18]
# Target:  17
# Moving pedestrian 16 26
# Movable neighbours:  5
# Static field values:  [15, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 16 27
# Movable neighbours:  5
# Static field values:  [16, 18, 17, 17, 18]
# Target:  16
# Moving pedestrian 16 31
# Movable neighbours:  6
# Static field values:  [15, 17, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 18 27
# Movable neighbours:  8
# Static field values:  [17, 17, 18, 18, 18, 19, 19, 19]
# Target:  17
# Moving pedestrian 18 31
# Movable neighbours:  8
# Static field values:  [17, 17, 17, 18, 18, 19, 19, 19]
# Target:  17
# Moving pedestrian 19 21
# Movable neighbours:  7
# Static field values:  [20, 19, 18, 20, 19, 20, 20]
# Target:  18
# Moving pedestrian 20 32
# Movable neighbours:  8
# Static field values:  [19, 19, 19, 20, 20, 21, 21, 21]
# Target:  19
# Moving pedestrian 21 13
# Movable neighbours:  8
# Static field values:  [20, 20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 22 17
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 25 25
# Movable neighbours:  6
# Static field values:  [24, 24, 24, 25, 26, 26]
# Target:  24
# Moving pedestrian 25 31
# Movable neighbours:  8
# Static field values:  [24, 24, 24, 25, 25, 26, 26, 26]
# Target:  24
# Moving pedestrian 26 22
# Movable neighbours:  6
# Static field values:  [25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 26 24
# Movable neighbours:  6
# Static field values:  [25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 26 33
# Movable neighbours:  8
# Static field values:  [25, 25, 25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 27 12
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 27 19
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 28 29
# Movable neighbours:  8
# Static field values:  [27, 27, 27, 28, 28, 29, 29, 29]
# Target:  27
# Moving pedestrian 29 13
# Movable neighbours:  6
# Static field values:  [28, 28, 28, 29, 29, 30]
# Target:  28
# Moving pedestrian 30 12
# Movable neighbours:  6
# Static field values:  [29, 29, 29, 31, 31, 31]
# Target:  29
# Moving pedestrian 31 28
# Movable neighbours:  6
# Static field values:  [30, 31, 31, 32, 32, 32]
# Target:  30
# Moving pedestrian 32 5
# Movable neighbours:  8
# Static field values:  [31, 31, 31, 32, 32, 33, 33, 33]
# Target:  31
# Moving pedestrian 32 12
# Movable neighbours:  8
# Static field values:  [31, 31, 31, 32, 32, 33, 33, 33]
# Target:  31
# Moving pedestrian 33 32
# Movable neighbours:  8
# Static field values:  [32, 32, 32, 33, 33, 34, 34, 34]
# Target:  32
# Moving pedestrian 3 16
# Movable neighbours:  8
# Static field values:  [15, 16, 17, 15, 17, 15, 16, 17]
# Target:  15
# Moving pedestrian 3 33
# Movable neighbours:  8
# Static field values:  [7, 6, 5, 7, 5, 7, 6, 5]
# Target:  5
# Moving pedestrian 5 6
# Movable neighbours:  7
# Static field values:  [5, 6, 7, 5, 6, 6, 7]
# Target:  5
# Moving pedestrian 5 10
# Movable neighbours:  7
# Static field values:  [9, 10, 11, 9, 9, 10, 11]
# Target:  9
# Moving pedestrian 5 16
# Movable neighbours:  8
# Static field values:  [15, 16, 17, 15, 17, 15, 16, 17]
# Target:  15
# Moving pedestrian 5 28
# Movable neighbours:  7
# Static field values:  [12, 11, 10, 12, 10, 12, 11]
# Target:  10
# Moving pedestrian 6 14
# Movable neighbours:  7
# Static field values:  [14, 15, 13, 15, 13, 14, 15]
# Target:  13
# Moving pedestrian 6 29
# Movable neighbours:  8
# Static field values:  [11, 10, 9, 11, 9, 11, 10, 9]
# Target:  9
# Moving pedestrian 6 31
# Movable neighbours:  7
# Static field values:  [8, 7, 9, 8, 9, 9, 8]
# Target:  7
# Moving pedestrian 7 33
# Movable neighbours:  8
# Static field values:  [8, 7, 6, 8, 7, 8, 8, 8]
# Target:  6
# Moving pedestrian 8 26
# Movable neighbours:  8
# Static field values:  [14, 13, 12, 14, 12, 14, 13, 12]
# Target:  12
# Moving pedestrian 8 29
# Movable neighbours:  8
# Static field values:  [11, 10, 9, 11, 10, 11, 11, 10]
# Target:  9
# Moving pedestrian 9 24
# Movable neighbours:  6
# Static field values:  [16, 15, 14, 16, 14, 16]
# Target:  14
# Moving pedestrian 10 4
# Movable neighbours:  7
# Static field values:  [9, 9, 9, 10, 11, 11, 11]
# Target:  9
# Moving pedestrian 10 24
# Movable neighbours:  7
# Static field values:  [16, 15, 14, 16, 16, 15, 14]
# Target:  14
# Moving pedestrian 11 26
# Movable neighbours:  7
# Static field values:  [13, 12, 14, 13, 14, 14, 13]
# Target:  12
# Moving pedestrian 11 32
# Movable neighbours:  7
# Static field values:  [10, 10, 10, 11, 11, 12, 12]
# Target:  10
# Moving pedestrian 12 3
# Movable neighbours:  8
# Static field values:  [11, 11, 11, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 12 5
# Movable neighbours:  8
# Static field values:  [11, 11, 11, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 12 29
# Movable neighbours:  8
# Static field values:  [12, 11, 11, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 12 31
# Movable neighbours:  8
# Static field values:  [11, 11, 11, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 13 11
# Movable neighbours:  8
# Static field values:  [12, 12, 13, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 15 4
# Movable neighbours:  8
# Static field values:  [14, 14, 14, 15, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 15 6
# Movable neighbours:  8
# Static field values:  [14, 14, 14, 15, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 15 13
# Movable neighbours:  8
# Static field values:  [14, 14, 15, 15, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 15 16
# Movable neighbours:  8
# Static field values:  [15, 16, 17, 16, 17, 16, 17, 17]
# Target:  15
# Moving pedestrian 15 22
# Movable neighbours:  8
# Static field values:  [18, 17, 16, 18, 17, 18, 18, 17]
# Target:  16
# Moving pedestrian 15 25
# Movable neighbours:  6
# Static field values:  [16, 15, 14, 16, 16, 16]
# Target:  14
# Moving pedestrian 15 32
# Movable neighbours:  7
# Static field values:  [14, 14, 14, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 16 26
# Movable neighbours:  5
# Static field values:  [15, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 17 26
# Movable neighbours:  8
# Static field values:  [16, 16, 17, 17, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 17 30
# Movable neighbours:  8
# Static field values:  [18, 17, 16, 18, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 18 22
# Movable neighbours:  8
# Static field values:  [19, 18, 17, 19, 18, 19, 19, 19]
# Target:  17
# Moving pedestrian 19 31
# Movable neighbours:  8
# Static field values:  [18, 18, 18, 19, 19, 20, 20, 20]
# Target:  18
# Moving pedestrian 20 12
# Movable neighbours:  8
# Static field values:  [19, 19, 19, 20, 20, 21, 21, 21]
# Target:  19
# Moving pedestrian 21 16
# Movable neighbours:  7
# Static field values:  [20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 24 24
# Movable neighbours:  5
# Static field values:  [23, 23, 23, 24, 24]
# Target:  23
# Moving pedestrian 24 30
# Movable neighbours:  8
# Static field values:  [23, 23, 23, 24, 24, 25, 25, 25]
# Target:  23
# Moving pedestrian 25 22
# Movable neighbours:  6
# Static field values:  [24, 24, 24, 26, 26, 26]
# Target:  24
# Moving pedestrian 25 25
# Movable neighbours:  7
# Static field values:  [24, 24, 24, 25, 26, 26, 26]
# Target:  24
# Moving pedestrian 25 32
# Movable neighbours:  8
# Static field values:  [24, 24, 24, 25, 25, 26, 26, 26]
# Target:  24
# Moving pedestrian 26 11
# Movable neighbours:  8
# Static field values:  [25, 25, 25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 26 18
# Movable neighbours:  8
# Static field values:  [25, 25, 25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 27 28
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 28 12
# Movable neighbours:  7
# Static field values:  [27, 27, 27, 28, 28, 29, 29]
# Target:  27
# Moving pedestrian 29 11
# Movable neighbours:  6
# Static field values:  [28, 28, 28, 29, 29, 30]
# Target:  28
# Moving pedestrian 30 27
# Movable neighbours:  7
# Static field values:  [29, 29, 29, 30, 31, 31, 31]
# Target:  29
# Moving pedestrian 31 4
# Movable neighbours:  8
# Static field values:  [30, 30, 30, 31, 31, 32, 32, 32]
# Target:  30
# Moving pedestrian 31 11
# Movable neighbours:  6
# Static field values:  [30, 31, 31, 32, 32, 32]
# Target:  30
# Moving pedestrian 32 31
# Movable neighbours:  8
# Static field values:  [31, 31, 31, 32, 32, 33, 33, 33]
# Target:  31
# Moving pedestrian 2 15
# Movable neighbours:  8
# Static field values:  [14, 15, 16, 14, 16, 14, 15, 16]
# Target:  14
# Moving pedestrian 2 34
# Movable neighbours:  8
# Static field values:  [6, 5, 4, 6, 4, 6, 5, 4]
# Target:  4
# Moving pedestrian 4 5
# Movable neighbours:  8
# Static field values:  [4, 5, 6, 4, 6, 5, 5, 6]
# Target:  4
# Moving pedestrian 4 9
# Movable neighbours:  8
# Static field values:  [8, 9, 10, 8, 10, 8, 9, 10]
# Target:  8
# Moving pedestrian 4 15
# Movable neighbours:  8
# Static field values:  [14, 15, 16, 14, 16, 14, 15, 16]
# Target:  14
# Moving pedestrian 4 29
# Movable neighbours:  7
# Static field values:  [11, 10, 9, 11, 9, 11, 10]
# Target:  9
# Moving pedestrian 5 30
# Movable neighbours:  8
# Static field values:  [10, 9, 8, 10, 8, 10, 9, 8]
# Target:  8
# Moving pedestrian 5 32
# Movable neighbours:  6
# Static field values:  [7, 6, 8, 8, 8, 7]
# Target:  6
# Moving pedestrian 6 13
# Movable neighbours:  7
# Static field values:  [12, 14, 12, 14, 12, 13, 14]
# Target:  12
# Moving pedestrian 6 34
# Movable neighbours:  6
# Static field values:  [5, 7, 6, 7, 7, 7]
# Target:  5
# Moving pedestrian 7 27
# Movable neighbours:  8
# Static field values:  [13, 12, 11, 13, 11, 13, 12, 11]
# Target:  11
# Moving pedestrian 7 30
# Movable neighbours:  8
# Static field values:  [10, 9, 8, 10, 9, 10, 10, 9]
# Target:  8
# Moving pedestrian 8 25
# Movable neighbours:  7
# Static field values:  [15, 14, 13, 15, 13, 15, 13]
# Target:  13
# Moving pedestrian 9 3
# Movable neighbours:  7
# Static field values:  [8, 8, 8, 9, 9, 10, 10]
# Target:  8
# Moving pedestrian 9 25
# Movable neighbours:  7
# Static field values:  [15, 14, 13, 15, 13, 15, 13]
# Target:  13
# Moving pedestrian 10 27
# Movable neighbours:  8
# Static field values:  [13, 12, 11, 13, 12, 13, 13, 12]
# Target:  11
# Moving pedestrian 10 31
# Movable neighbours:  7
# Static field values:  [10, 9, 9, 10, 10, 11, 11]
# Target:  9
# Moving pedestrian 11 2
# Movable neighbours:  6
# Static field values:  [10, 11, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 11 4
# Movable neighbours:  7
# Static field values:  [10, 10, 11, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 11 29
# Movable neighbours:  7
# Static field values:  [12, 11, 10, 12, 12, 12, 12]
# Target:  10
# Moving pedestrian 11 30
# Movable neighbours:  7
# Static field values:  [11, 10, 11, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 12 10
# Movable neighbours:  8
# Static field values:  [11, 11, 12, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 14 3
# Movable neighbours:  8
# Static field values:  [13, 13, 13, 14, 14, 15, 15, 15]
# Target:  13
# Moving pedestrian 14 5
# Movable neighbours:  8
# Static field values:  [13, 13, 13, 14, 14, 15, 15, 15]
# Target:  13
# Moving pedestrian 14 12
# Movable neighbours:  8
# Static field values:  [13, 13, 14, 14, 14, 15, 15, 15]
# Target:  13
# Moving pedestrian 14 15
# Movable neighbours:  8
# Static field values:  [14, 15, 16, 15, 16, 15, 16, 16]
# Target:  14
# Moving pedestrian 14 23
# Movable neighbours:  8
# Static field values:  [17, 16, 15, 17, 16, 17, 17, 16]
# Target:  15
# Moving pedestrian 14 26
# Movable neighbours:  5
# Static field values:  [15, 14, 13, 15, 14]
# Target:  13
# Moving pedestrian 14 31
# Movable neighbours:  6
# Static field values:  [13, 13, 13, 14, 14, 15]
# Target:  13
# Moving pedestrian 15 25
# Movable neighbours:  6
# Static field values:  [16, 15, 14, 16, 16, 16]
# Target:  14
# Moving pedestrian 16 25
# Movable neighbours:  7
# Static field values:  [16, 15, 16, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 16 31
# Movable neighbours:  6
# Static field values:  [15, 17, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 17 23
# Movable neighbours:  8
# Static field values:  [18, 17, 16, 18, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 18 30
# Movable neighbours:  8
# Static field values:  [18, 17, 17, 18, 18, 19, 19, 19]
# Target:  17
# Moving pedestrian 19 11
# Movable neighbours:  8
# Static field values:  [18, 18, 18, 19, 19, 20, 20, 20]
# Target:  18
# Moving pedestrian 20 15
# Movable neighbours:  7
# Static field values:  [19, 19, 19, 20, 21, 21, 21]
# Target:  19
# Moving pedestrian 23 23
# Movable neighbours:  7
# Static field values:  [22, 22, 22, 23, 23, 24, 24]
# Target:  22
# Moving pedestrian 23 29
# Movable neighbours:  8
# Static field values:  [22, 22, 22, 23, 23, 24, 24, 24]
# Target:  22
# Moving pedestrian 24 21
# Movable neighbours:  7
# Static field values:  [23, 23, 23, 24, 24, 25, 25]
# Target:  23
# Moving pedestrian 24 24
# Movable neighbours:  6
# Static field values:  [23, 23, 23, 24, 24, 25]
# Target:  23
# Moving pedestrian 24 31
# Movable neighbours:  8
# Static field values:  [23, 23, 23, 24, 24, 25, 25, 25]
# Target:  23
# Moving pedestrian 25 10
# Movable neighbours:  8
# Static field values:  [24, 24, 24, 25, 25, 26, 26, 26]
# Target:  24
# Moving pedestrian 25 17
# Movable neighbours:  8
# Static field values:  [24, 24, 24, 25, 25, 26, 26, 26]
# Target:  24
# Moving pedestrian 26 27
# Movable neighbours:  8
# Static field values:  [25, 25, 25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 27 11
# Movable neighbours:  7
# Static field values:  [26, 26, 26, 27, 27, 28, 28]
# Target:  26
# Moving pedestrian 28 10
# Movable neighbours:  8
# Static field values:  [27, 27, 27, 28, 28, 29, 29, 29]
# Target:  27
# Moving pedestrian 29 26
# Movable neighbours:  7
# Static field values:  [28, 28, 28, 29, 29, 30, 30]
# Target:  28
# Moving pedestrian 30 3
# Movable neighbours:  7
# Static field values:  [29, 29, 29, 30, 31, 31, 31]
# Target:  29
# Moving pedestrian 30 12
# Movable neighbours:  6
# Static field values:  [29, 29, 29, 31, 31, 31]
# Target:  29
# Moving pedestrian 31 30
# Movable neighbours:  7
# Static field values:  [30, 30, 31, 31, 32, 32, 32]
# Target:  30
# Moving pedestrian 1 14
# Movable neighbours:  8
# Static field values:  [1000, 1000, 1000, 13, 15, 13, 14, 15]
# Target:  13
# Moving pedestrian 1 35
# Movable neighbours:  7
# Static field values:  [1000, 1000, 5, 3, 5, 4, 3]
# Target:  3
# Moving pedestrian 1 36
# Moving pedestrian 3 4
# Movable neighbours:  8
# Static field values:  [3, 4, 5, 3, 5, 4, 4, 5]
# Target:  3
# Moving pedestrian 3 8
# Movable neighbours:  8
# Static field values:  [7, 8, 9, 7, 9, 7, 8, 9]
# Target:  7
# Moving pedestrian 3 14
# Movable neighbours:  8
# Static field values:  [13, 14, 15, 13, 15, 13, 14, 15]
# Target:  13
# Moving pedestrian 3 30
# Movable neighbours:  7
# Static field values:  [10, 9, 8, 10, 8, 10, 9]
# Target:  8
# Moving pedestrian 4 31
# Movable neighbours:  8
# Static field values:  [9, 8, 7, 9, 7, 9, 8, 7]
# Target:  7
# Moving pedestrian 4 33
# Movable neighbours:  5
# Static field values:  [6, 5, 7, 5, 7]
# Target:  5
# Moving pedestrian 5 12
# Movable neighbours:  6
# Static field values:  [11, 12, 13, 11, 12, 13]
# Target:  11
# Moving pedestrian 5 35
# Movable neighbours:  6
# Static field values:  [5, 4, 4, 6, 6, 6]
# Target:  4
# Moving pedestrian 6 28
# Movable neighbours:  8
# Static field values:  [12, 11, 10, 12, 10, 12, 11, 10]
# Target:  10
# Moving pedestrian 6 31
# Movable neighbours:  8
# Static field values:  [9, 8, 7, 9, 8, 9, 9, 8]
# Target:  7
# Moving pedestrian 7 26
# Movable neighbours:  7
# Static field values:  [14, 13, 12, 14, 12, 14, 12]
# Target:  12
# Moving pedestrian 8 2
# Movable neighbours:  8
# Static field values:  [7, 7, 7, 8, 8, 9, 9, 9]
# Target:  7
# Moving pedestrian 8 26
# Movable neighbours:  8
# Static field values:  [14, 13, 12, 14, 12, 14, 13, 12]
# Target:  12
# Moving pedestrian 9 28
# Movable neighbours:  8
# Static field values:  [12, 11, 10, 12, 11, 12, 12, 11]
# Target:  10
# Moving pedestrian 9 31
# Movable neighbours:  6
# Static field values:  [10, 9, 8, 10, 9, 10]
# Target:  8
# Moving pedestrian 10 2
# Movable neighbours:  6
# Static field values:  [9, 9, 9, 11, 11, 11]
# Target:  9
# Moving pedestrian 10 4
# Movable neighbours:  7
# Static field values:  [9, 9, 9, 10, 11, 11, 11]
# Target:  9
# Moving pedestrian 10 30
# Movable neighbours:  7
# Static field values:  [11, 10, 9, 11, 11, 11, 11]
# Target:  9
# Moving pedestrian 10 31
# Movable neighbours:  7
# Static field values:  [10, 9, 10, 10, 11, 11, 11]
# Target:  9
# Moving pedestrian 11 9
# Movable neighbours:  7
# Static field values:  [10, 10, 11, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 13 2
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 13 4
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 13 11
# Movable neighbours:  8
# Static field values:  [12, 12, 13, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 13 14
# Movable neighbours:  8
# Static field values:  [13, 14, 15, 14, 15, 14, 15, 15]
# Target:  13
# Moving pedestrian 13 24
# Movable neighbours:  8
# Static field values:  [16, 15, 14, 16, 15, 16, 16, 15]
# Target:  14
# Moving pedestrian 13 27
# Movable neighbours:  7
# Static field values:  [14, 13, 12, 14, 13, 14, 14]
# Target:  12
# Moving pedestrian 13 30
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 14 26
# Movable neighbours:  5
# Static field values:  [15, 14, 13, 15, 14]
# Target:  13
# Moving pedestrian 15 25
# Movable neighbours:  6
# Static field values:  [16, 15, 14, 16, 16, 16]
# Target:  14
# Moving pedestrian 15 32
# Movable neighbours:  7
# Static field values:  [14, 14, 14, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 16 24
# Movable neighbours:  8
# Static field values:  [17, 16, 15, 17, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 17 30
# Movable neighbours:  8
# Static field values:  [18, 17, 16, 18, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 18 10
# Movable neighbours:  8
# Static field values:  [17, 17, 17, 18, 18, 19, 19, 19]
# Target:  17
# Moving pedestrian 19 14
# Movable neighbours:  8
# Static field values:  [18, 18, 18, 19, 19, 20, 20, 20]
# Target:  18
# Moving pedestrian 22 22
# Movable neighbours:  7
# Static field values:  [21, 21, 21, 22, 22, 23, 23]
# Target:  21
# Moving pedestrian 22 28
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 23 20
# Movable neighbours:  8
# Static field values:  [22, 22, 22, 23, 23, 24, 24, 24]
# Target:  22
# Moving pedestrian 23 23
# Movable neighbours:  8
# Static field values:  [22, 22, 22, 23, 23, 24, 24, 24]
# Target:  22
# Moving pedestrian 23 30
# Movable neighbours:  8
# Static field values:  [22, 22, 22, 23, 23, 24, 24, 24]
# Target:  22
# Moving pedestrian 24 9
# Movable neighbours:  8
# Static field values:  [23, 23, 23, 24, 24, 25, 25, 25]
# Target:  23
# Moving pedestrian 24 16
# Movable neighbours:  7
# Static field values:  [23, 23, 23, 24, 24, 25, 25]
# Target:  23
# Moving pedestrian 25 26
# Movable neighbours:  8
# Static field values:  [24, 24, 24, 25, 25, 26, 26, 26]
# Target:  24
# Moving pedestrian 26 10
# Movable neighbours:  7
# Static field values:  [25, 25, 25, 26, 26, 27, 27]
# Target:  25
# Moving pedestrian 27 9
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 28 25
# Movable neighbours:  8
# Static field values:  [27, 27, 27, 28, 28, 29, 29, 29]
# Target:  27
# Moving pedestrian 29 2
# Movable neighbours:  7
# Static field values:  [28, 28, 28, 29, 29, 30, 30]
# Target:  28
# Moving pedestrian 29 11
# Movable neighbours:  6
# Static field values:  [28, 28, 28, 29, 29, 30]
# Target:  28
# Moving pedestrian 30 30
# Movable neighbours:  7
# Static field values:  [29, 29, 29, 30, 31, 31, 31]
# Target:  29
# Moving pedestrian 1 13
# Movable neighbours:  6
# Static field values:  [1000, 1000, 12, 14, 12, 14]
# Target:  12
# Moving pedestrian 1 36
# Movable neighbours:  6
# Static field values:  [1000, 4, 2, 4, 3, 2]
# Target:  2
# Moving pedestrian 1 37
# Moving pedestrian 2 3
# Movable neighbours:  8
# Static field values:  [2, 3, 4, 2, 4, 3, 3, 4]
# Target:  2
# Moving pedestrian 2 7
# Movable neighbours:  8
# Static field values:  [6, 7, 8, 6, 8, 6, 7, 8]
# Target:  6
# Moving pedestrian 2 13
# Movable neighbours:  7
# Static field values:  [13, 14, 12, 14, 12, 13, 14]
# Target:  12
# Moving pedestrian 2 31
# Movable neighbours:  7
# Static field values:  [9, 8, 7, 9, 7, 9, 8]
# Target:  7
# Moving pedestrian 3 32
# Movable neighbours:  8
# Static field values:  [8, 7, 6, 8, 6, 8, 7, 6]
# Target:  6
# Moving pedestrian 3 34
# Movable neighbours:  6
# Static field values:  [5, 4, 6, 4, 6, 5]
# Target:  4
# Moving pedestrian 4 11
# Movable neighbours:  7
# Static field values:  [10, 11, 12, 10, 12, 10, 12]
# Target:  10
# Moving pedestrian 4 35
# Movable neighbours:  6
# Static field values:  [5, 4, 3, 5, 4, 5]
# Target:  3
# Moving pedestrian 5 29
# Movable neighbours:  8
# Static field values:  [11, 10, 9, 11, 9, 11, 10, 9]
# Target:  9
# Moving pedestrian 5 32
# Movable neighbours:  7
# Static field values:  [8, 7, 6, 8, 8, 8, 7]
# Target:  6
# Moving pedestrian 6 27
# Movable neighbours:  6
# Static field values:  [12, 11, 13, 11, 13, 11]
# Target:  11
# Moving pedestrian 7 1
# Movable neighbours:  8
# Static field values:  [1000, 6, 6, 1000, 7, 1000, 8, 8]
# Target:  6
# Moving pedestrian 7 27
# Movable neighbours:  8
# Static field values:  [13, 12, 11, 13, 11, 13, 12, 11]
# Target:  11
# Moving pedestrian 8 29
# Movable neighbours:  8
# Static field values:  [11, 10, 9, 11, 10, 11, 11, 10]
# Target:  9
# Moving pedestrian 8 32
# Movable neighbours:  6
# Static field values:  [9, 8, 7, 9, 8, 9]
# Target:  7
# Moving pedestrian 9 1
# Movable neighbours:  7
# Static field values:  [1000, 8, 8, 1000, 9, 1000, 10]
# Target:  8
# Moving pedestrian 9 3
# Movable neighbours:  7
# Static field values:  [8, 8, 8, 9, 9, 10, 10]
# Target:  8
# Moving pedestrian 9 31
# Movable neighbours:  7
# Static field values:  [10, 9, 8, 10, 10, 10, 10]
# Target:  8
# Moving pedestrian 9 32
# Movable neighbours:  7
# Static field values:  [9, 8, 9, 9, 10, 10, 10]
# Target:  8
# Moving pedestrian 10 8
# Movable neighbours:  8
# Static field values:  [9, 9, 9, 10, 10, 11, 11, 11]
# Target:  9
# Moving pedestrian 12 1
# Movable neighbours:  8
# Static field values:  [1000, 11, 11, 1000, 12, 1000, 13, 13]
# Target:  11
# Moving pedestrian 12 3
# Movable neighbours:  8
# Static field values:  [11, 11, 11, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 12 10
# Movable neighbours:  8
# Static field values:  [11, 11, 12, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 12 13
# Movable neighbours:  8
# Static field values:  [12, 13, 14, 13, 14, 13, 14, 14]
# Target:  12
# Moving pedestrian 12 25
# Movable neighbours:  8
# Static field values:  [15, 14, 13, 15, 14, 15, 15, 14]
# Target:  13
# Moving pedestrian 12 28
# Movable neighbours:  6
# Static field values:  [13, 12, 11, 13, 13, 13]
# Target:  11
# Moving pedestrian 12 29
# Movable neighbours:  7
# Static field values:  [12, 11, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 13 27
# Movable neighbours:  7
# Static field values:  [14, 13, 12, 14, 13, 14, 14]
# Target:  12
# Moving pedestrian 14 26
# Movable neighbours:  5
# Static field values:  [15, 14, 13, 15, 14]
# Target:  13
# Moving pedestrian 14 31
# Movable neighbours:  6
# Static field values:  [13, 13, 13, 14, 14, 15]
# Target:  13
# Moving pedestrian 15 25
# Movable neighbours:  7
# Static field values:  [16, 15, 14, 16, 16, 16, 16]
# Target:  14
# Moving pedestrian 16 31
# Movable neighbours:  6
# Static field values:  [15, 17, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 17 9
# Movable neighbours:  8
# Static field values:  [16, 16, 16, 17, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 18 13
# Movable neighbours:  8
# Static field values:  [17, 17, 17, 18, 18, 19, 19, 19]
# Target:  17
# Moving pedestrian 21 21
# Movable neighbours:  6
# Static field values:  [20, 20, 21, 21, 22, 22]
# Target:  20
# Moving pedestrian 21 27
# Movable neighbours:  8
# Static field values:  [20, 20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 22 19
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 22 22
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 22 29
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 23 8
# Movable neighbours:  8
# Static field values:  [22, 22, 22, 23, 23, 24, 24, 24]
# Target:  22
# Moving pedestrian 23 15
# Movable neighbours:  8
# Static field values:  [22, 22, 22, 23, 23, 24, 24, 24]
# Target:  22
# Moving pedestrian 24 25
# Movable neighbours:  7
# Static field values:  [23, 23, 23, 24, 24, 25, 25]
# Target:  23
# Moving pedestrian 25 9
# Movable neighbours:  7
# Static field values:  [24, 24, 24, 25, 25, 26, 26]
# Target:  24
# Moving pedestrian 26 8
# Movable neighbours:  8
# Static field values:  [25, 25, 25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 27 24
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 28 1
# Movable neighbours:  8
# Static field values:  [1000, 27, 27, 1000, 28, 1000, 29, 29]
# Target:  27
# Moving pedestrian 28 10
# Movable neighbours:  8
# Static field values:  [27, 27, 27, 28, 28, 29, 29, 29]
# Target:  27
# Moving pedestrian 29 29
# Movable neighbours:  6
# Static field values:  [28, 28, 28, 29, 29, 30]
# Target:  28
# Moving pedestrian 1 2
# Movable neighbours:  7
# Static field values:  [1000, 1000, 1, 3, 2, 2, 3]
# Target:  1
# Moving pedestrian 1 6
# Movable neighbours:  8
# Static field values:  [1000, 1000, 1000, 5, 7, 5, 6, 7]
# Target:  5
# Moving pedestrian 1 12
# Movable neighbours:  6
# Static field values:  [1000, 1000, 11, 13, 11, 13]
# Target:  11
# Moving pedestrian 1 32
# Movable neighbours:  6
# Static field values:  [1000, 1000, 8, 6, 8, 7]
# Target:  6
# Moving pedestrian 1 33
# Moving pedestrian 1 37
# Movable neighbours:  6
# Static field values:  [1000, 3, 1, 3, 2, 2]
# Target:  1
# Moving pedestrian 1 38
# Moving pedestrian 2 12
# Movable neighbours:  7
# Static field values:  [12, 13, 11, 13, 11, 12, 13]
# Target:  11
# Moving pedestrian 2 33
# Movable neighbours:  7
# Static field values:  [7, 5, 7, 5, 7, 6, 5]
# Target:  5
# Moving pedestrian 2 35
# Movable neighbours:  6
# Static field values:  [4, 3, 5, 3, 5, 4]
# Target:  3
# Moving pedestrian 3 10
# Movable neighbours:  7
# Static field values:  [9, 10, 9, 11, 9, 10, 11]
# Target:  9
# Moving pedestrian 3 36
# Movable neighbours:  8
# Static field values:  [4, 3, 2, 4, 3, 4, 4, 4]
# Target:  2
# Moving pedestrian 4 30
# Movable neighbours:  8
# Static field values:  [10, 9, 8, 10, 8, 10, 9, 8]
# Target:  8
# Moving pedestrian 4 33
# Movable neighbours:  6
# Static field values:  [7, 6, 5, 7, 5, 7]
# Target:  5
# Moving pedestrian 5 28
# Movable neighbours:  7
# Static field values:  [12, 11, 10, 12, 10, 12, 10]
# Target:  10
# Moving pedestrian 6 1
# Movable neighbours:  6
# Static field values:  [5, 1000, 6, 1000, 7, 7]
# Target:  5
# Moving pedestrian 6 28
# Movable neighbours:  8
# Static field values:  [12, 11, 10, 12, 10, 12, 11, 10]
# Target:  10
# Moving pedestrian 7 30
# Movable neighbours:  8
# Static field values:  [10, 9, 8, 10, 9, 10, 10, 9]
# Target:  8
# Moving pedestrian 7 33
# Movable neighbours:  6
# Static field values:  [8, 7, 6, 8, 7, 8]
# Target:  6
# Moving pedestrian 8 1
# Movable neighbours:  7
# Static field values:  [1000, 7, 7, 1000, 1000, 9, 9]
# Target:  7
# Moving pedestrian 8 2
# Movable neighbours:  7
# Static field values:  [7, 7, 8, 8, 9, 9, 9]
# Target:  7
# Moving pedestrian 8 32
# Movable neighbours:  7
# Static field values:  [9, 8, 7, 9, 9, 9, 9]
# Target:  7
# Moving pedestrian 8 33
# Movable neighbours:  7
# Static field values:  [8, 7, 8, 8, 9, 9, 9]
# Target:  7
# Moving pedestrian 9 7
# Movable neighbours:  8
# Static field values:  [8, 8, 8, 9, 9, 10, 10, 10]
# Target:  8
# Moving pedestrian 11 1
# Movable neighbours:  6
# Static field values:  [1000, 10, 1000, 1000, 12, 12]
# Target:  10
# Moving pedestrian 11 2
# Movable neighbours:  5
# Static field values:  [11, 11, 12, 12, 12]
# Target:  11
# Moving pedestrian 11 9
# Movable neighbours:  7
# Static field values:  [10, 10, 11, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 11 12
# Movable neighbours:  8
# Static field values:  [11, 12, 13, 12, 13, 12, 13, 13]
# Target:  11
# Moving pedestrian 11 26
# Movable neighbours:  7
# Static field values:  [13, 12, 14, 13, 14, 14, 13]
# Target:  12
# Moving pedestrian 11 29
# Movable neighbours:  6
# Static field values:  [12, 11, 10, 12, 12, 12]
# Target:  10
# Moving pedestrian 11 30
# Movable neighbours:  7
# Static field values:  [11, 10, 11, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 12 28
# Movable neighbours:  7
# Static field values:  [13, 12, 11, 13, 12, 13, 13]
# Target:  11
# Moving pedestrian 13 27
# Movable neighbours:  7
# Static field values:  [14, 13, 12, 14, 13, 14, 14]
# Target:  12
# Moving pedestrian 13 30
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 14 26
# Movable neighbours:  6
# Static field values:  [15, 14, 13, 15, 14, 15]
# Target:  13
# Moving pedestrian 15 32
# Movable neighbours:  7
# Static field values:  [14, 14, 14, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 16 8
# Movable neighbours:  8
# Static field values:  [15, 15, 15, 16, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 17 12
# Movable neighbours:  8
# Static field values:  [16, 16, 16, 17, 17, 18, 18, 18]
# Target:  16
# Moving pedestrian 20 20
# Movable neighbours:  6
# Static field values:  [20, 20, 19, 20, 21, 21]
# Target:  19
# Moving pedestrian 20 26
# Movable neighbours:  8
# Static field values:  [19, 19, 19, 20, 20, 21, 21, 21]
# Target:  19
# Moving pedestrian 21 18
# Movable neighbours:  8
# Static field values:  [20, 20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 21 21
# Movable neighbours:  7
# Static field values:  [20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 21 28
# Movable neighbours:  8
# Static field values:  [20, 20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 22 7
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 22 14
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 23 24
# Movable neighbours:  8
# Static field values:  [22, 22, 22, 23, 23, 24, 24, 24]
# Target:  22
# Moving pedestrian 24 8
# Movable neighbours:  7
# Static field values:  [23, 23, 23, 24, 24, 25, 25]
# Target:  23
# Moving pedestrian 25 7
# Movable neighbours:  8
# Static field values:  [24, 24, 24, 25, 25, 26, 26, 26]
# Target:  24
# Moving pedestrian 26 23
# Movable neighbours:  6
# Static field values:  [25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 27 1
# Movable neighbours:  8
# Static field values:  [1000, 26, 26, 1000, 27, 1000, 28, 28]
# Target:  26
# Moving pedestrian 27 9
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 28 28
# Movable neighbours:  8
# Static field values:  [27, 27, 27, 28, 28, 29, 29, 29]
# Target:  27
# Moving pedestrian 1 1
# Movable neighbours:  7
# Static field values:  [0, 1000, 1000, 2, 1000, 2, 2]
# Target:  0
# Moving pedestrian 1 5
# Movable neighbours:  8
# Static field values:  [1000, 1000, 1000, 4, 6, 4, 5, 6]
# Target:  4
# Moving pedestrian 1 11
# Movable neighbours:  6
# Static field values:  [1000, 1000, 10, 12, 10, 12]
# Target:  10
# Moving pedestrian 1 33
# Movable neighbours:  6
# Static field values:  [1000, 1000, 7, 7, 6, 5]
# Target:  5
# Moving pedestrian 1 34
# Movable neighbours:  7
# Static field values:  [1000, 1000, 1000, 6, 4, 6, 4]
# Target:  4
# Moving pedestrian 1 35
# Moving pedestrian 1 36
# Movable neighbours:  4
# Static field values:  [1000, 2, 4, 3]
# Target:  2
# Moving pedestrian 1 37
# Moving pedestrian 1 38
# Movable neighbours:  5
# Static field values:  [1000, 0, 1000, 2, 1000]
# Target:  0
# Moving pedestrian 2 9
# Movable neighbours:  7
# Static field values:  [8, 9, 8, 10, 8, 9, 10]
# Target:  8
# Moving pedestrian 2 11
# Movable neighbours:  7
# Static field values:  [11, 12, 10, 12, 10, 11, 12]
# Target:  10
# Moving pedestrian 2 34
# Moving pedestrian 2 37
# Movable neighbours:  7
# Static field values:  [3, 1, 3, 2, 3, 3, 3]
# Target:  1
# Moving pedestrian 3 31
# Movable neighbours:  8
# Static field values:  [9, 8, 7, 9, 7, 9, 8, 7]
# Target:  7
# Moving pedestrian 3 34
# Movable neighbours:  7
# Static field values:  [6, 4, 6, 4, 6, 5, 4]
# Target:  4
# Moving pedestrian 4 29
# Movable neighbours:  7
# Static field values:  [11, 10, 9, 11, 9, 11, 9]
# Target:  9
# Moving pedestrian 5 1
# Movable neighbours:  6
# Static field values:  [1000, 4, 4, 1000, 6, 6]
# Target:  4
# Moving pedestrian 5 29
# Movable neighbours:  8
# Static field values:  [11, 10, 9, 11, 9, 11, 10, 9]
# Target:  9
# Moving pedestrian 6 31
# Movable neighbours:  8
# Static field values:  [9, 8, 7, 9, 8, 9, 9, 8]
# Target:  7
# Moving pedestrian 6 34
# Movable neighbours:  4
# Static field values:  [5, 7, 6, 7]
# Target:  5
# Moving pedestrian 7 1
# Movable neighbours:  7
# Static field values:  [1000, 6, 6, 1000, 1000, 8, 8]
# Target:  6
# Moving pedestrian 7 2
# Movable neighbours:  7
# Static field values:  [6, 6, 7, 7, 8, 8, 8]
# Target:  6
# Moving pedestrian 7 33
# Movable neighbours:  7
# Static field values:  [8, 7, 6, 8, 8, 8, 8]
# Target:  6
# Moving pedestrian 7 34
# Movable neighbours:  7
# Static field values:  [7, 6, 7, 7, 8, 8, 8]
# Target:  6
# Moving pedestrian 8 6
# Movable neighbours:  8
# Static field values:  [7, 7, 7, 8, 8, 9, 9, 9]
# Target:  7
# Moving pedestrian 10 2
# Movable neighbours:  5
# Static field values:  [9, 9, 9, 11, 11]
# Target:  9
# Moving pedestrian 10 8
# Movable neighbours:  8
# Static field values:  [9, 9, 9, 10, 10, 11, 11, 11]
# Target:  9
# Moving pedestrian 10 11
# Movable neighbours:  7
# Static field values:  [10, 11, 12, 12, 11, 12, 12]
# Target:  10
# Moving pedestrian 10 27
# Movable neighbours:  8
# Static field values:  [13, 12, 11, 13, 12, 13, 13, 12]
# Target:  11
# Moving pedestrian 10 30
# Movable neighbours:  6
# Static field values:  [11, 10, 9, 11, 11, 11]
# Target:  9
# Moving pedestrian 10 31
# Movable neighbours:  7
# Static field values:  [10, 9, 10, 10, 11, 11, 11]
# Target:  9
# Moving pedestrian 11 1
# Movable neighbours:  7
# Static field values:  [1000, 10, 1000, 11, 1000, 12, 12]
# Target:  10
# Moving pedestrian 11 29
# Movable neighbours:  6
# Static field values:  [12, 11, 10, 12, 11, 12]
# Target:  10
# Moving pedestrian 12 28
# Movable neighbours:  6
# Static field values:  [13, 12, 11, 13, 13, 13]
# Target:  11
# Moving pedestrian 12 29
# Movable neighbours:  7
# Static field values:  [12, 11, 12, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 13 27
# Movable neighbours:  8
# Static field values:  [14, 13, 12, 14, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 14 31
# Movable neighbours:  6
# Static field values:  [13, 13, 13, 14, 14, 15]
# Target:  13
# Moving pedestrian 15 7
# Movable neighbours:  8
# Static field values:  [14, 14, 14, 15, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 16 11
# Movable neighbours:  8
# Static field values:  [15, 15, 15, 16, 16, 17, 17, 17]
# Target:  15
# Moving pedestrian 19 21
# Movable neighbours:  6
# Static field values:  [20, 19, 18, 20, 19, 20]
# Target:  18
# Moving pedestrian 19 25
# Movable neighbours:  8
# Static field values:  [18, 18, 18, 19, 19, 20, 20, 20]
# Target:  18
# Moving pedestrian 20 17
# Movable neighbours:  7
# Static field values:  [19, 19, 19, 20, 21, 21, 21]
# Target:  19
# Moving pedestrian 20 20
# Movable neighbours:  7
# Static field values:  [20, 20, 19, 20, 21, 21, 21]
# Target:  19
# Moving pedestrian 20 27
# Movable neighbours:  8
# Static field values:  [19, 19, 19, 20, 20, 21, 21, 21]
# Target:  19
# Moving pedestrian 21 6
# Movable neighbours:  8
# Static field values:  [20, 20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 21 13
# Movable neighbours:  8
# Static field values:  [20, 20, 20, 21, 21, 22, 22, 22]
# Target:  20
# Moving pedestrian 22 23
# Movable neighbours:  8
# Static field values:  [21, 21, 21, 22, 22, 23, 23, 23]
# Target:  21
# Moving pedestrian 23 7
# Movable neighbours:  7
# Static field values:  [22, 22, 22, 23, 23, 24, 24]
# Target:  22
# Moving pedestrian 24 6
# Movable neighbours:  8
# Static field values:  [23, 23, 23, 24, 24, 25, 25, 25]
# Target:  23
# Moving pedestrian 25 22
# Movable neighbours:  6
# Static field values:  [24, 24, 24, 26, 26, 26]
# Target:  24
# Moving pedestrian 26 1
# Movable neighbours:  8
# Static field values:  [1000, 25, 25, 1000, 26, 1000, 27, 27]
# Target:  25
# Moving pedestrian 26 8
# Movable neighbours:  8
# Static field values:  [25, 25, 25, 26, 26, 27, 27, 27]
# Target:  25
# Moving pedestrian 27 27
# Movable neighbours:  8
# Static field values:  [26, 26, 26, 27, 27, 28, 28, 28]
# Target:  26
# Moving pedestrian 1 4
# Movable neighbours:  8
# Static field values:  [1000, 1000, 1000, 3, 5, 3, 4, 5]
# Target:  3
# Moving pedestrian 1 8
# Movable neighbours:  8
# Static field values:  [1000, 1000, 1000, 7, 9, 7, 8, 9]
# Target:  7
# Moving pedestrian 1 10
# Movable neighbours:  7
# Static field values:  [1000, 1000, 1000, 9, 11, 9, 11]
# Target:  9
# Moving pedestrian 1 35
# Movable neighbours:  5
# Static field values:  [1000, 1000, 5, 3, 3]
# Target:  3
# Moving pedestrian 1 36
# Moving pedestrian 1 37
# Movable neighbours:  4
# Static field values:  [1000, 3, 2, 2]
# Target:  2
# Moving pedestrian 1 38
# Movable neighbours:  6
# Static field values:  [1000, 0, 2, 1000, 2, 1000]
# Target:  0
# Moving pedestrian 2 10
# Movable neighbours:  7
# Static field values:  [10, 11, 9, 11, 9, 10, 11]
# Target:  9
# Moving pedestrian 2 32
# Movable neighbours:  8
# Static field values:  [8, 7, 6, 8, 6, 8, 7, 6]
# Target:  6
# Moving pedestrian 2 34
# Movable neighbours:  6
# Static field values:  [5, 4, 6, 6, 5, 4]
# Target:  4
# Moving pedestrian 2 35
# Movable neighbours:  6
# Static field values:  [5, 5, 3, 5, 4, 3]
# Target:  3
# Moving pedestrian 2 36
# Moving pedestrian 2 37
# Moving pedestrian 3 30
# Movable neighbours:  7
# Static field values:  [10, 9, 8, 10, 8, 10, 8]
# Target:  8
# Moving pedestrian 4 1
# Movable neighbours:  6
# Static field values:  [1000, 3, 3, 1000, 4, 5]
# Target:  3
# Moving pedestrian 4 30
# Movable neighbours:  8
# Static field values:  [10, 9, 8, 10, 8, 10, 9, 8]
# Target:  8
# Moving pedestrian 5 32
# Movable neighbours:  7
# Static field values:  [8, 7, 6, 8, 8, 8, 7]
# Target:  6
# Moving pedestrian 5 35
# Movable neighbours:  4
# Static field values:  [5, 4, 4, 6]
# Target:  4
# Moving pedestrian 6 1
# Movable neighbours:  5
# Static field values:  [5, 1000, 1000, 7, 7]
# Target:  5
# Moving pedestrian 6 2
# Movable neighbours:  6
# Static field values:  [5, 6, 6, 7, 7, 7]
# Target:  5
# Moving pedestrian 6 34
# Movable neighbours:  5
# Static field values:  [5, 7, 7, 7, 7]
# Target:  5
# Moving pedestrian 6 35
# Movable neighbours:  5
# Static field values:  [6, 6, 7, 7, 7]
# Target:  6
# Moving pedestrian 7 5
# Movable neighbours:  8
# Static field values:  [6, 6, 6, 7, 7, 8, 8, 8]
# Target:  6
# Moving pedestrian 9 1
# Movable neighbours:  6
# Static field values:  [1000, 8, 8, 1000, 9, 1000]
# Target:  8
# Moving pedestrian 9 7
# Movable neighbours:  8
# Static field values:  [8, 8, 8, 9, 9, 10, 10, 10]
# Target:  8
# Moving pedestrian 9 10
# Movable neighbours:  7
# Static field values:  [9, 10, 11, 9, 11, 10, 11]
# Target:  9
# Moving pedestrian 9 28
# Movable neighbours:  8
# Static field values:  [12, 11, 10, 12, 11, 12, 12, 11]
# Target:  10
# Moving pedestrian 9 31
# Movable neighbours:  6
# Static field values:  [10, 9, 8, 10, 10, 10]
# Target:  8
# Moving pedestrian 9 32
# Movable neighbours:  7
# Static field values:  [9, 8, 9, 9, 10, 10, 10]
# Target:  8
# Moving pedestrian 10 2
# Movable neighbours:  6
# Static field values:  [9, 9, 9, 11, 11, 11]
# Target:  9
# Moving pedestrian 10 30
# Movable neighbours:  6
# Static field values:  [11, 10, 9, 11, 10, 11]
# Target:  9
# Moving pedestrian 11 29
# Movable neighbours:  6
# Static field values:  [12, 11, 10, 12, 12, 12]
# Target:  10
# Moving pedestrian 11 30
# Movable neighbours:  7
# Static field values:  [11, 10, 11, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 12 28
# Movable neighbours:  8
# Static field values:  [13, 12, 11, 13, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 13 30
# Movable neighbours:  8
# Static field values:  [12, 12, 12, 13, 13, 14, 14, 14]
# Target:  12
# Moving pedestrian 14 6
# Movable neighbours:  8
# Static field values:  [13, 13, 13, 14, 14, 15, 15, 15]
# Target:  13
# Moving pedestrian 15 10
# Movable neighbours:  8
# Static field values:  [14, 14, 14, 15, 15, 16, 16, 16]
# Target:  14
# Moving pedestrian 18 22
# Movable neighbours:  7
# Static field values:  [19, 18, 17, 19, 18, 19, 19]
# Target:  17
# Moving pedestrian 18 24
# Movable neighbours:  7
# Static field values:  [17, 17, 18, 18, 19, 19, 19]
# Target:  17
# Moving pedestrian 19 16
# Movable neighbours:  7
# Static field values:  [18, 18, 18, 19, 19, 20, 20]
# Target:  18
# Moving pedestrian 19 21
# Movable neighbours:  7
# ...
# Target:  7
# Moving pedestrian 9 1
# Movable neighbours:  7
# Static field values:  [1000, 8, 8, 1000, 9, 1000, 10]
# Target:  8
# Moving pedestrian 10 7
# Movable neighbours:  8
# Static field values:  [9, 9, 9, 10, 10, 11, 11, 11]
# Target:  9
# Moving pedestrian 11 1
# Movable neighbours:  6
# Static field values:  [1000, 10, 1000, 1000, 12, 12]
# Target:  10
# Moving pedestrian 11 2
# Movable neighbours:  5
# Static field values:  [11, 11, 12, 12, 12]
# Target:  11
# Moving pedestrian 12 28
# Movable neighbours:  8
# Static field values:  [13, 12, 11, 13, 12, 13, 13, 13]
# Target:  11
# Moving pedestrian 1 1
# Movable neighbours:  6
# Static field values:  [0, 1000, 1000, 1000, 2, 2]
# Target:  0
# Moving pedestrian 1 2
# Movable neighbours:  7
# Static field values:  [1000, 1000, 1, 3, 2, 2, 3]
# Target:  1
# Moving pedestrian 1 35
# Movable neighbours:  6
# Static field values:  [1000, 1000, 5, 5, 4, 3]
# Target:  3
# Moving pedestrian 1 36
# Movable neighbours:  3
# Static field values:  [1000, 4, 4]
# Target:  4
# Moving pedestrian 1 37
# Movable neighbours:  2
# Static field values:  [3, 2]
# Target:  2
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 36
# Moving pedestrian 2 37
# Movable neighbours:  4
# Static field values:  [3, 2, 1, 3]
# Target:  1
# Moving pedestrian 2 38
# Moving pedestrian 3 34
# Movable neighbours:  6
# Static field values:  [6, 5, 4, 6, 4, 5]
# Target:  4
# Moving pedestrian 3 36
# Movable neighbours:  4
# Static field values:  [2, 4, 4, 4]
# Target:  2
# Moving pedestrian 3 37
# Movable neighbours:  5
# Static field values:  [3, 3, 4, 4, 4]
# Target:  3
# Moving pedestrian 4 2
# Movable neighbours:  5
# Static field values:  [3, 3, 3, 4, 4]
# Target:  3
# Moving pedestrian 4 33
# Movable neighbours:  6
# Static field values:  [7, 6, 5, 7, 5, 7]
# Target:  5
# Moving pedestrian 4 35
# Movable neighbours:  4
# Static field values:  [4, 5, 4, 5]
# Target:  4
# Moving pedestrian 5 1
# Movable neighbours:  6
# Static field values:  [1000, 4, 4, 1000, 6, 6]
# Target:  4
# Moving pedestrian 5 3
# Movable neighbours:  7
# Static field values:  [4, 4, 4, 5, 6, 6, 6]
# Target:  4
# Moving pedestrian 6 34
# Movable neighbours:  6
# Static field values:  [5, 7, 6, 7, 7, 7]
# Target:  5
# Moving pedestrian 7 1
# Movable neighbours:  7
# Static field values:  [1000, 6, 6, 1000, 7, 1000, 8]
# Target:  6
# Moving pedestrian 8 1
# Movable neighbours:  8
# Static field values:  [1000, 7, 7, 1000, 8, 1000, 9, 9]
# Target:  7
# Moving pedestrian 9 6
# Movable neighbours:  8
# Static field values:  [8, 8, 8, 9, 9, 10, 10, 10]
# Target:  8
# Moving pedestrian 10 2
# Movable neighbours:  5
# Static field values:  [9, 9, 9, 11, 11]
# Target:  9
# Moving pedestrian 11 1
# Movable neighbours:  7
# Static field values:  [1000, 10, 1000, 11, 1000, 12, 12]
# Target:  10
# Moving pedestrian 11 29
# Movable neighbours:  8
# Static field values:  [12, 11, 10, 12, 11, 12, 12, 12]
# Target:  10
# Moving pedestrian 1 1
# Movable neighbours:  7
# Static field values:  [0, 1000, 1000, 2, 1000, 2, 2]
# Target:  0
# Moving pedestrian 1 35
# Movable neighbours:  5
# Static field values:  [1000, 1000, 5, 3, 5]
# Target:  3
# Moving pedestrian 1 36
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 35
# Movable neighbours:  3
# Static field values:  [5, 4, 5]
# Target:  4
# Moving pedestrian 2 36
# Movable neighbours:  3
# Static field values:  [2, 4, 3]
# Target:  2
# Moving pedestrian 2 37
# Movable neighbours:  4
# Static field values:  [1, 3, 3, 3]
# Target:  1
# Moving pedestrian 2 38
# Movable neighbours:  6
# Static field values:  [1000, 2, 1000, 3, 3, 1000]
# Target:  2
# Moving pedestrian 3 1
# Movable neighbours:  6
# Static field values:  [1000, 2, 2, 1000, 3, 1000]
# Target:  2
# Moving pedestrian 3 34
# Movable neighbours:  7
# Static field values:  [6, 5, 4, 6, 6, 5, 4]
# Target:  4
# Moving pedestrian 3 35
# Movable neighbours:  6
# Static field values:  [5, 3, 5, 5, 4, 4]
# Target:  3
# Moving pedestrian 3 36
# Movable neighbours:  5
# Static field values:  [4, 3, 4, 4, 4]
# Target:  3
# Moving pedestrian 3 37
# Moving pedestrian 4 1
# Movable neighbours:  5
# Static field values:  [1000, 3, 3, 1000, 5]
# Target:  3
# Moving pedestrian 4 2
# Movable neighbours:  6
# Static field values:  [3, 3, 4, 4, 5, 5]
# Target:  3
# Moving pedestrian 5 35
# Movable neighbours:  6
# Static field values:  [5, 4, 4, 6, 6, 6]
# Target:  4
# Moving pedestrian 6 1
# Movable neighbours:  5
# Static field values:  [5, 1000, 6, 1000, 7]
# Target:  5
# Moving pedestrian 7 1
# Movable neighbours:  8
# Static field values:  [1000, 6, 6, 1000, 7, 1000, 8, 8]
# Target:  6
# Moving pedestrian 8 5
# Movable neighbours:  8
# Static field values:  [7, 7, 7, 8, 8, 9, 9, 9]
# Target:  7
# Moving pedestrian 9 1
# Movable neighbours:  6
# Static field values:  [1000, 8, 8, 1000, 9, 1000]
# Target:  8
# Moving pedestrian 10 2
# Movable neighbours:  6
# Static field values:  [9, 9, 9, 11, 11, 11]
# Target:  9
# Moving pedestrian 10 30
# Movable neighbours:  8
# Static field values:  [11, 10, 9, 11, 10, 11, 11, 11]
# Target:  9
# Moving pedestrian 1 35
# Movable neighbours:  4
# Static field values:  [1000, 1000, 5, 5]
# Target:  5
# Moving pedestrian 1 36
# Movable neighbours:  2
# Static field values:  [1000, 4]
# Target:  4
# Moving pedestrian 1 37
# Movable neighbours:  2
# Static field values:  [3, 2]
# Target:  2
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 1
# Movable neighbours:  6
# Static field values:  [1000, 1, 2, 1000, 2, 1000]
# Target:  1
# Moving pedestrian 2 35
# Movable neighbours:  5
# Static field values:  [3, 5, 5, 4, 3]
# Target:  3
# Moving pedestrian 2 36
# Movable neighbours:  4
# Static field values:  [2, 4, 4, 3]
# Target:  2
# Moving pedestrian 2 37
# Movable neighbours:  4
# Static field values:  [1, 3, 3, 3]
# Target:  1
# Moving pedestrian 2 38
# Moving pedestrian 3 1
# Movable neighbours:  7
# Static field values:  [1000, 2, 2, 1000, 1000, 4, 4]
# Target:  2
# Moving pedestrian 3 2
# Movable neighbours:  7
# Static field values:  [2, 3, 3, 3, 4, 4, 4]
# Target:  2
# Moving pedestrian 3 37
# Movable neighbours:  7
# Static field values:  [3, 2, 3, 3, 4, 4, 4]
# Target:  2
# Moving pedestrian 4 35
# Movable neighbours:  6
# Static field values:  [5, 4, 3, 5, 4, 5]
# Target:  3
# Moving pedestrian 5 1
# Movable neighbours:  5
# Static field values:  [1000, 4, 4, 1000, 6]
# Target:  4
# Moving pedestrian 6 1
# Movable neighbours:  6
# Static field values:  [5, 1000, 6, 1000, 7, 7]
# Target:  5
# Moving pedestrian 7 4
# Movable neighbours:  8
# Static field values:  [6, 6, 6, 7, 7, 8, 8, 8]
# Target:  6
# Moving pedestrian 8 1
# Movable neighbours:  7
# Static field values:  [1000, 7, 7, 1000, 8, 1000, 9]
# Target:  7
# Moving pedestrian 9 1
# Movable neighbours:  7
# Static field values:  [1000, 8, 8, 1000, 9, 1000, 10]
# Target:  8
# Moving pedestrian 9 31
# Movable neighbours:  8
# Static field values:  [10, 9, 8, 10, 9, 10, 10, 10]
# Target:  8
# Moving pedestrian 1 1
# Movable neighbours:  5
# Static field values:  [0, 1000, 1000, 2, 1000]
# Target:  0
# Moving pedestrian 1 34
# Movable neighbours:  7
# Static field values:  [1000, 1000, 1000, 6, 6, 5, 4]
# Target:  4
# Moving pedestrian 1 35
# Movable neighbours:  5
# Static field values:  [1000, 1000, 5, 5, 3]
# Target:  3
# Moving pedestrian 1 36
# Movable neighbours:  2
# Static field values:  [1000, 4]
# Target:  4
# Moving pedestrian 1 37
# Movable neighbours:  1
# Static field values:  [3]
# Target:  3
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 1
# Movable neighbours:  7
# Static field values:  [1000, 1, 2, 1000, 1000, 3, 3]
# Target:  1
# Moving pedestrian 2 2
# Movable neighbours:  7
# Static field values:  [2, 3, 2, 3, 3, 3, 3]
# Target:  2
# Moving pedestrian 2 35
# Moving pedestrian 2 36
# Moving pedestrian 2 37
# Movable neighbours:  4
# Static field values:  [2, 1, 3, 3]
# Target:  1
# Moving pedestrian 2 38
# Movable neighbours:  7
# Static field values:  [2, 1000, 2, 1000, 3, 3, 1000]
# Target:  2
# Moving pedestrian 3 36
# Movable neighbours:  6
# Static field values:  [2, 4, 3, 4, 4, 4]
# Target:  2
# Moving pedestrian 4 1
# Movable neighbours:  5
# Static field values:  [1000, 3, 3, 1000, 4]
# Target:  3
# Moving pedestrian 5 1
# Movable neighbours:  6
# Static field values:  [1000, 4, 4, 1000, 6, 6]
# Target:  4
# Moving pedestrian 6 3
# Movable neighbours:  7
# Static field values:  [5, 5, 6, 6, 7, 7, 7]
# Target:  5
# Moving pedestrian 7 1
# Movable neighbours:  7
# Static field values:  [1000, 6, 6, 1000, 7, 1000, 8]
# Target:  6
# Moving pedestrian 8 1
# Movable neighbours:  8
# Static field values:  [1000, 7, 7, 1000, 8, 1000, 9, 9]
# Target:  7
# Moving pedestrian 8 32
# Movable neighbours:  8
# Static field values:  [9, 8, 7, 9, 8, 9, 9, 9]
# Target:  7
# Moving pedestrian 1 1
# Movable neighbours:  6
# Static field values:  [0, 1000, 1000, 1000, 2, 2]
# Target:  0
# Moving pedestrian 1 2
# Movable neighbours:  7
# Static field values:  [1000, 1000, 1, 3, 2, 2, 3]
# Target:  1
# Moving pedestrian 1 35
# Movable neighbours:  4
# Static field values:  [1000, 1000, 5, 5]
# Target:  5
# Moving pedestrian 1 36
# Movable neighbours:  2
# Static field values:  [1000, 4]
# Target:  4
# Moving pedestrian 1 37
# Movable neighbours:  2
# Static field values:  [3, 2]
# Target:  2
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 35
# Movable neighbours:  5
# Static field values:  [3, 5, 5, 4, 3]
# Target:  3
# Moving pedestrian 2 36
# Movable neighbours:  5
# Static field values:  [2, 4, 4, 3, 3]
# Target:  2
# Moving pedestrian 2 37
# Movable neighbours:  5
# Static field values:  [1, 3, 3, 3, 3]
# Target:  1
# Moving pedestrian 2 38
# Moving pedestrian 3 1
# Movable neighbours:  7
# Static field values:  [1000, 2, 2, 1000, 3, 1000, 4]
# Target:  2
# Moving pedestrian 4 1
# Movable neighbours:  6
# Static field values:  [1000, 3, 3, 1000, 4, 5]
# Target:  3
# Moving pedestrian 5 3
# Movable neighbours:  7
# Static field values:  [4, 4, 4, 5, 6, 6, 6]
# Target:  4
# Moving pedestrian 6 1
# Movable neighbours:  5
# Static field values:  [5, 1000, 6, 1000, 7]
# Target:  5
# Moving pedestrian 7 1
# Movable neighbours:  8
# Static field values:  [1000, 6, 6, 1000, 7, 1000, 8, 8]
# Target:  6
# Moving pedestrian 7 33
# Movable neighbours:  8
# Static field values:  [8, 7, 6, 8, 7, 8, 8, 8]
# Target:  6
# Moving pedestrian 1 1
# Movable neighbours:  6
# Static field values:  [0, 1000, 1000, 2, 1000, 2]
# Target:  0
# Moving pedestrian 1 34
# Movable neighbours:  7
# Static field values:  [1000, 1000, 1000, 6, 6, 5, 4]
# Target:  4
# Moving pedestrian 1 35
# Movable neighbours:  5
# Static field values:  [1000, 1000, 5, 5, 3]
# Target:  3
# Moving pedestrian 1 36
# Movable neighbours:  3
# Static field values:  [1000, 4, 2]
# Target:  2
# Moving pedestrian 1 37
# Movable neighbours:  1
# Static field values:  [3]
# Target:  3
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 1
# Movable neighbours:  7
# Static field values:  [1000, 1, 2, 1000, 2, 1000, 3]
# Target:  1
# Moving pedestrian 2 35
# Moving pedestrian 2 36
# Moving pedestrian 2 37
# Moving pedestrian 2 38
# Movable neighbours:  7
# Static field values:  [2, 1, 1000, 1000, 3, 3, 1000]
# Target:  1
# Moving pedestrian 3 1
# Movable neighbours:  7
# Static field values:  [1000, 2, 2, 1000, 3, 1000, 4]
# Target:  2
# Moving pedestrian 4 2
# Movable neighbours:  6
# Static field values:  [3, 3, 3, 4, 4, 5]
# Target:  3
# Moving pedestrian 5 1
# Movable neighbours:  5
# Static field values:  [1000, 4, 4, 1000, 6]
# Target:  4
# Moving pedestrian 6 1
# Movable neighbours:  6
# Static field values:  [5, 1000, 6, 1000, 7, 7]
# Target:  5
# Moving pedestrian 6 34
# Movable neighbours:  6
# Static field values:  [5, 7, 6, 7, 7, 7]
# Target:  5
# Moving pedestrian 1 1
# Movable neighbours:  6
# Static field values:  [0, 1000, 1000, 2, 1000, 2]
# Target:  0
# Moving pedestrian 1 36
# Movable neighbours:  3
# Static field values:  [1000, 4, 2]
# Target:  2
# Moving pedestrian 1 37
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 1000, 2, 1000]
# Target:  0
# Moving pedestrian 2 1
# Movable neighbours:  7
# Static field values:  [1000, 1, 2, 1000, 2, 1000, 3]
# Target:  1
# Moving pedestrian 2 35
# Movable neighbours:  7
# Static field values:  [5, 4, 3, 5, 5, 4, 3]
# Target:  3
# Moving pedestrian 2 36
# Movable neighbours:  5
# Static field values:  [4, 4, 4, 3, 3]
# Target:  3
# Moving pedestrian 2 37
# Movable neighbours:  5
# Static field values:  [1, 3, 2, 3, 3]
# Target:  1
# Moving pedestrian 3 1
# Movable neighbours:  7
# Static field values:  [1000, 2, 2, 1000, 3, 1000, 4]
# Target:  2
# Moving pedestrian 3 36
# Moving pedestrian 4 1
# Movable neighbours:  5
# Static field values:  [1000, 3, 3, 1000, 4]
# Target:  3
# Moving pedestrian 5 1
# Movable neighbours:  6
# Static field values:  [1000, 4, 4, 1000, 6, 6]
# Target:  4
# Moving pedestrian 5 35
# Movable neighbours:  6
# Static field values:  [5, 4, 4, 6, 6, 6]
# Target:  4
# Moving pedestrian 1 1
# Movable neighbours:  6
# Static field values:  [0, 1000, 1000, 2, 1000, 2]
# Target:  0
# Moving pedestrian 1 36
# Movable neighbours:  5
# Static field values:  [1000, 4, 4, 3, 2]
# Target:  2
# Moving pedestrian 1 37
# Movable neighbours:  3
# Static field values:  [3, 3, 2]
# Target:  2
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 1
# Movable neighbours:  7
# Static field values:  [1000, 1, 2, 1000, 2, 1000, 3]
# Target:  1
# Moving pedestrian 2 37
# Moving pedestrian 2 38
# Moving pedestrian 3 1
# Movable neighbours:  7
# Static field values:  [1000, 2, 2, 1000, 3, 1000, 4]
# Target:  2
# Moving pedestrian 3 36
# Movable neighbours:  6
# Static field values:  [4, 3, 4, 3, 4, 4]
# Target:  3
# Moving pedestrian 4 1
# Movable neighbours:  6
# Static field values:  [1000, 3, 3, 1000, 4, 5]
# Target:  3
# Moving pedestrian 4 35
# Movable neighbours:  6
# Static field values:  [5, 4, 3, 5, 4, 5]
# Target:  3
# Moving pedestrian 1 1
# Movable neighbours:  6
# Static field values:  [0, 1000, 1000, 2, 1000, 2]
# Target:  0
# Moving pedestrian 2 1
# Movable neighbours:  7
# Static field values:  [1000, 1, 2, 1000, 2, 1000, 3]
# Target:  1
# Moving pedestrian 2 36
# Movable neighbours:  6
# Static field values:  [4, 3, 2, 4, 4, 3]
# Target:  2
# Moving pedestrian 2 37
# Movable neighbours:  5
# Static field values:  [3, 1, 3, 3, 3]
# Target:  1
# Moving pedestrian 2 38
# Movable neighbours:  6
# Static field values:  [1000, 2, 1000, 3, 3, 1000]
# Target:  2
# Moving pedestrian 3 1
# Movable neighbours:  8
# Static field values:  [1000, 2, 2, 1000, 3, 1000, 4, 4]
# Target:  2
# Moving pedestrian 3 36
# Movable neighbours:  7
# Static field values:  [4, 3, 4, 3, 4, 4, 4]
# Target:  3
# Moving pedestrian 1 1
# Movable neighbours:  6
# Static field values:  [0, 1000, 1000, 2, 1000, 2]
# Target:  0
# Moving pedestrian 1 37
# Movable neighbours:  2
# Static field values:  [3, 2]
# Target:  2
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 1
# Movable neighbours:  8
# Static field values:  [1000, 1, 2, 1000, 2, 1000, 3, 3]
# Target:  1
# Moving pedestrian 2 36
# Movable neighbours:  7
# Static field values:  [4, 3, 2, 4, 4, 3, 3]
# Target:  2
# Moving pedestrian 2 37
# Movable neighbours:  6
# Static field values:  [3, 1, 3, 3, 3, 3]
# Target:  1
# Moving pedestrian 2 38
# Moving pedestrian 1 1
# Movable neighbours:  7
# Static field values:  [0, 1000, 1000, 2, 1000, 2, 2]
# Target:  0
# Moving pedestrian 1 37
# Movable neighbours:  3
# Static field values:  [3, 3, 2]
# Target:  2
# Moving pedestrian 1 38
# Movable neighbours:  4
# Static field values:  [0, 2, 1000, 1000]
# Target:  0
# Moving pedestrian 2 37
# Moving pedestrian 2 38
# Movable neighbours:  7
# Static field values:  [2, 1, 1000, 1000, 3, 3, 1000]
# Target:  1
# Moving pedestrian 1 38
# Movable neighbours:  5
# Static field values:  [0, 2, 1000, 2, 1000]
# Target:  0
# Moving pedestrian 2 37
# Movable neighbours:  8
# Static field values:  [3, 2, 1, 3, 2, 3, 3, 3]
# Target:  1
# Moving pedestrian 1 38
# Movable neighbours:  6
# Static field values:  [0, 2, 1000, 2, 2, 1000]
# Target:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 40
#      37 pygame.time.set_timer(timer_event, time_delay )
#      39 while running:
# ---> 40     for event in pygame.event.get():
#      41         if event.type == QUIT:
#      42             running = False
#
# KeyboardInterrupt:

# %%
# print board
np.set_printoptions(suppress=True)
with np.printoptions(threshold=np.inf):
    print(board.getPointTypes())

# %%
# print static field values
np.set_printoptions(suppress=True)
with np.printoptions(threshold=np.inf):
    print(board.getFloorFieldValues())
